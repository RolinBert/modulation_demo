# %%
from numpy import arange, sin, pi
import matplotlib.pyplot as plt
from modulation import DigitalModulation

# %%
mod = DigitalModulation()

apsk = mod.get_ask_mod([0,1,1,1,0,0,1,0])

# %%
plt.plot(apsk)

# %%
fsk = mod.get_fsk_mod([0,1,1,1,0,0,1,0], 500e3)
plt.plot(fsk)
